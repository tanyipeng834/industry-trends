# %% [markdown]
# <h1 align = "center"><b>DS102 Project</b></h1>
# <h3 align = "center"><i>Topic: Study of Employment Trends Versus Choice of Study Among Tertiary Students</i></h3>
# <h6 align = "center"> By: Chen Shiying Alicia, Tan Yi Peng, Jeremy Chow Jun Yong, Wilson Wee Yi An, Lee Eileen (8 Nov 2020, 4pm - Group 3)</h3>

# %% [markdown]
# ## I. Problem Statement / Research Topic

# %% [markdown]
# **<u>What research topic are we going to address?</u>**
#
# <p>The Singapore economy has been growing throughout the years, with more foreign companies choosing the country to plant their roots in Asia, and also with the emergence of more local startups and unicorns. Technology has been evolving at an unprecedented rate, the job market too is ever changing to accommodate the requirements of the organisations’ operations. We want to take a deeper look into the employment trends, particularly with young tertiary graduates.</p>

# %% [markdown]
# **<u>Why are we interested to research on this topic in this region/country?</u>**
#
# <p> The data is readily available and easily accessible in Singapore and our results will not be impacted by the different states, regions or provinces like in some other countries. Our analysis will be more concise and more relevant to our targeted readers. It also gives us a better perspective as young adults on how the Singapore IT industry has changed over the years.</p>

# %% [markdown]
# **<u>Why is this topic interesting to us or why are we passionate to research on this topic?</u>**
#
# <p>It is well known that information technology and its related services have seen an increase in popularity as many firms seek to digitalise and modernise themselves. We would like to see if there are any obvious trends related to the employment rate of the IT industry as well as if there is an incease in number of IT graduates, and if the two are related.</p>

# %% [markdown]
# ### Hypothesis

# %% [markdown]
# **<u>Hypothesis I</u>**
#
# <p>We will analyse if a change in number of IT graduates directly affects the recruitment rate and employment change of the IT industry. Also, we will check if a change in employment rate or recruitment rate for the IT industry might influence students' decisions in picking their course of study, leading to a change in student intake for IT related courses. </p>

# %% [markdown]
# **<u>Hypothesis II</u>**
# <p>We will also take a look at the proportion of female enrolment for IT related courses in polytechnics and universities to see if there are any trends.
# </p>

# %% [markdown]
# ### Assumptions
#  - Students enrolled in a course will join the industry that they studied for.
#  - The scope of study will be limited to the IT industry, hence course in focus for studying will directly corresponds to Information Technology.

# %% [markdown]
# ## II. Dataset and Data Preparation
# ####  Source datasets used:

# %% [markdown]
# <br>1. <a href="https://data.gov.sg/dataset/polytechnics-intake-enrolment-and-graduates-by-course">Polytechnics - Intake, Enrolment and Graduates by Course </a>
#     <br> File Type: csv </br>
#     <br> Range of Years: 2005 to 2019 </br>
#     <br> Dataset describes intake, enrolment and graduates of polytechnics by course. </br>
#     <table>
#     <tr>
#         <th> Column Name</th>
#         <th> Data Type</th></tr>
#         <tr><td> Year</td>
#             <td> Datetime (Year) "YYYY" </td></tr>
#          <tr><td> Sex </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Course </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Intake </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Enrolment </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Graduates </td>
#             <td> Text (General) </td></tr>
#       </table></br></p>

# %% [markdown]
# <br>2. <a href="https://data.gov.sg/dataset/universities-intake-enrolment-and-graduates-by-course">Universities - Intake, Enrolment and Graduates by Course </a>
#     <br> File Type: csv </br>
#     <br> Range of Years: 2005 to 2019 </br>
#     <br> Dataset describes intake, enrolment and graduates of universities by course. </br>
#     <table>
#     <tr>
#         <th> Column Name</th>
#         <th> Data Type</th></tr>
#         <tr><td> Year</td>
#             <td> Datetime (Year) "YYYY" </td></tr>
#          <tr><td> Sex </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Course </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Intake </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Enrolment </td>
#             <td> Text (General) </td></tr>
#         <tr><td> Graduates </td>
#             <td> Text (General) </td></tr>
#       </table></br></p>

# %% [markdown]
# <br>3. <a href="https://data.gov.sg/dataset/employment-change-by-industry-annual">Employment Change By Industry, Annual (December to December) </a>
#     <br> File Type: csv </br>
#     <br> Range of Years: 1991 to 2019 </br>
#     <br> Dataset describes annual change in employment by industry </br>
#     <table>
#     <tr>
#         <th> Column Name</th>
#         <th> Data Type</th></tr>
#         <tr><td> Year</td>
#             <td> Datetime (Year)"YYYY"</td></tr>
#          <tr><td> Industry1 </td>
#              <td> Text (General)</td></tr>
#         <tr><td> Industry2 </td>
#             <td> Text (General)</td></tr>
#         <tr><td> Industry3 </td>
#             <td> Text (General)</td></tr>
#         <tr><td> Employment Change</td>
#             <td> Numeric (General)</td></tr>
#        </table></br></p>

# %% [markdown]
# <br>4. <a href="https://data.gov.sg/dataset/average-monthly-recruitment-resignation-rates-by-industry-and-occupational-group-annual?resource_id=243896d0-1974-4fee-a4d8-613641b230ad">Average Monthly Recruitment/Resignation Rates by Industry and Occupational Group, Annual</a>
#     <br> File Type: csv </br>
#     <br> Range of Years: 1990 to 2019 </br>
#     <br> Dataset describes annual rate in recruitment and resignation by industry. </br>
#     <table>
#     <tr>
#         <th> Column Name</th>
#         <th> Data Type</th></tr>
#         <tr><td> Year</td>
#             <td> Datetime (Year)"YYYY"</td></tr>
#          <tr><td> Industry1 </td>
#              <td> Text (General)</td></tr>
#         <tr><td> Industry2 </td>
#             <td> Text (General)</td></tr>
#         <tr><td> Industry3 </td>
#             <td> Text (General)</td></tr>
#         <tr><td> Recruitment Rate</td>
#             <td> Numeric (Percentage)</td></tr>
#         <tr><td> Resignation Rate</td>
#             <td> Numeric (Percentage)</td></tr>
#        </table></br></p>

# %% [markdown]
# ## III. Methodology

# %% [markdown]
# - To study the course intake as a whole, we will consolidate datasets 1 & 2 mentioned in Section II into a single dataframe. It is made simple as both datasets have the same columns. Similarly, datasets 3 & 4 will be combined to form another dataframe to analyse the respective industry trends.

# %% [markdown]
# ### Manipulation of Student Datasets

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#import uni intake datasetS
uni_intake_df = pd.read_csv('universities-intake-enrolment-and-graduates-by-course.csv', thousands=',')
uni_intake_df.head()
# Out:
#    year sex                                course  intake  enrolment  \
# 0  2005  MF                           Accountancy     876       2561
# 1  2005   F                           Accountancy     530       1732
# 2  2005  MF  Architecture, Building & Real Estate     299       1310
# 3  2005   F  Architecture, Building & Real Estate     175        786
# 4  2005  MF             Business & Administration    1545       5013
#
#    graduates
# 0        706
# 1        495
# 2        180
# 3        106
# 4       1256

# %%
#observe the uni DF
display(uni_intake_df.dtypes)
display(uni_intake_df.shape)
display(uni_intake_df.isnull().sum())
display(uni_intake_df['course'].unique())
# Out:
# year          int64
# sex          object
# course       object
# intake        int64
# enrolment     int64
# graduates     int64
# dtype: object
# (450, 6)
# year         0
# sex          0
# course       0
# intake       0
# enrolment    0
# graduates    0
# dtype: int64
# array(['Accountancy', 'Architecture, Building & Real Estate',
#        'Business & Administration', 'Dentistry', 'Education',
#        'Engineering Sciences', 'Fine & Applied Arts', 'Health Sciences',
#        'Humanities & Social Sciences', 'Information Technology', 'Law',
#        'Mass Communication', 'Medicine',
#        'Natural, Physical & Mathematical Sciences', 'Services'],
#       dtype=object)

# %%
#add uni column to DF
uni_intake_df['tertiary type'] = uni_intake_df['course'].apply(lambda x: "University")
uni_intake_df.head()
# Out:
#    year sex                                course  intake  enrolment  \
# 0  2005  MF                           Accountancy     876       2561
# 1  2005   F                           Accountancy     530       1732
# 2  2005  MF  Architecture, Building & Real Estate     299       1310
# 3  2005   F  Architecture, Building & Real Estate     175        786
# 4  2005  MF             Business & Administration    1545       5013
#
#    graduates tertiary type
# 0        706    University
# 1        495    University
# 2        180    University
# 3        106    University
# 4       1256    University

# %%
#import poly intake dataset
poly_intake_df = pd.read_csv('polytechnics-intake-enrolment-and-graduates-by-course.csv', thousands = ',')
poly_intake_df.head()
# Out:
#    year sex                                course  intake  enrolment  \
# 0  2005  MF                          Applied Arts    1128       2593
# 1  2005   F                          Applied Arts     687       1538
# 2  2005  MF  Architecture, Building & Real Estate     515       1466
# 3  2005   F  Architecture, Building & Real Estate     312        870
# 4  2005  MF             Business & Administration    3483      10143
#
#    graduates
# 0        550
# 1        302
# 2        425
# 3        249
# 4       3044

# %%
#observe the poly DF
display(poly_intake_df.dtypes)
display(poly_intake_df.shape)
display(poly_intake_df.isnull().sum())
display(poly_intake_df['course'].unique())
# Out:
# year          int64
# sex          object
# course       object
# intake        int64
# enrolment     int64
# graduates     int64
# dtype: object
# (360, 6)
# year         0
# sex          0
# course       0
# intake       0
# enrolment    0
# graduates    0
# dtype: int64
# array(['Applied Arts', 'Architecture, Building & Real Estate',
#        'Business & Administration', 'Education', 'Engineering Sciences',
#        'Health Sciences', 'Humanities & Social Sciences',
#        'Information Technology', 'Law', 'Mass Communication',
#        'Natural, Physical & Mathematical Sciences', 'Services'],
#       dtype=object)

# %%
# add poly column to DF
poly_intake_df['tertiary type'] = uni_intake_df['course'].apply(lambda x: "Polytechnic")
poly_intake_df.head()
# Out:
#    year sex                                course  intake  enrolment  \
# 0  2005  MF                          Applied Arts    1128       2593
# 1  2005   F                          Applied Arts     687       1538
# 2  2005  MF  Architecture, Building & Real Estate     515       1466
# 3  2005   F  Architecture, Building & Real Estate     312        870
# 4  2005  MF             Business & Administration    3483      10143
#
#    graduates tertiary type
# 0        550   Polytechnic
# 1        302   Polytechnic
# 2        425   Polytechnic
# 3        249   Polytechnic
# 4       3044   Polytechnic

# %%
# concatenate uni and poly DFs
combined_intake_df = pd.concat([uni_intake_df, poly_intake_df])
combined_intake_df.reset_index(drop=True)
# Out:
#      year sex                                     course  intake  enrolment  \
# 0    2005  MF                                Accountancy     876       2561
# 1    2005   F                                Accountancy     530       1732
# 2    2005  MF       Architecture, Building & Real Estate     299       1310
# 3    2005   F       Architecture, Building & Real Estate     175        786
# 4    2005  MF                  Business & Administration    1545       5013
# ..    ...  ..                                        ...     ...        ...
# 805  2019   F                     Information Technology     730       2412
# 806  2019   F                                        Law      69        200
# 807  2019   F                         Mass Communication     437       1396
# 808  2019   F  Natural, Physical & Mathematical Sciences     691       2200
# 809  2019   F                                   Services     375       1312
#
#      graduates tertiary type
# ...

# %%
# create DF with total cohort only + from years 2010 - 2019 + only selected courses 

#filter to sex MF only
total_intake_df = combined_intake_df.loc[combined_intake_df['sex'] == 'MF']

# filter further to only years 2010 - 2019
mask = (total_intake_df['year'] > 2009) & (total_intake_df['year'] <= 2019)
total_intake_df = total_intake_df.loc[mask]

# filter to course information technology 
total_intake_df= total_intake_df[total_intake_df['course'] == 'Information Technology']
                                
total_intake_df.reset_index(drop=True)
# Out:
#     year sex                  course  intake  enrolment  graduates  \
# 0   2010  MF  Information Technology     939       3355        631
# 1   2011  MF  Information Technology    1057       3643        583
# 2   2012  MF  Information Technology    1028       3853        764
# 3   2013  MF  Information Technology    1086       4058        824
# 4   2014  MF  Information Technology    1166       4152        997
# 5   2015  MF  Information Technology    1247       4541       1066
# 6   2016  MF  Information Technology    1379       4810       1051
# 7   2017  MF  Information Technology    1579       5360        977
# 8   2018  MF  Information Technology    2039       6143       1244
# 9   2019  MF  Information Technology    2520       7386       1186
# 10  2010  MF  Information Technology    3687      11885       3693
# 11  2011  MF  Information Technology    3942      11689       3732
# 12  2012  MF  Information Technology    3976      11677       3642
# ...

# %%
female_intake_df = combined_intake_df.loc[combined_intake_df['sex'] == 'F']

# filter further to only years 2010 - 2019
mask = (female_intake_df['year'] > 2009) & (female_intake_df['year'] <= 2019)
female_intake_df = female_intake_df.loc[mask]

# filter to course information technology 
female_intake_df= female_intake_df[female_intake_df['course'] == 'Information Technology']
                                
female_intake_df.reset_index(drop=True)
# Out:
#     year sex                  course  intake  enrolment  graduates  \
# 0   2010   F  Information Technology     276       1068        162
# 1   2011   F  Information Technology     364       1178        195
# 2   2012   F  Information Technology     354       1236        280
# 3   2013   F  Information Technology     351       1321        251
# 4   2014   F  Information Technology     343       1343        289
# 5   2015   F  Information Technology     389       1492        377
# 6   2016   F  Information Technology     398       1499        381
# 7   2017   F  Information Technology     448       1599        330
# 8   2018   F  Information Technology     685       1905        373
# 9   2019   F  Information Technology     874       2374        383
# 10  2010   F  Information Technology    1586       5117       1586
# 11  2011   F  Information Technology    1626       4939       1607
# 12  2012   F  Information Technology    1559       4797       1580
# ...

# %%
#Getting data for proportion of females for each year of enrolment.
female_enrolment = female_intake_df['enrolment']
female_df = pd.DataFrame(female_enrolment)
female_df = female_df.reset_index(drop=True)

overall_enrolment = total_intake_df['enrolment']
overall_df = pd.DataFrame(overall_enrolment)
overall_df = overall_df.reset_index(drop=True)

proportion = (female_df / overall_df) * 100
proportion
# Out:
#     enrolment
# 0   31.833085
# 1   32.335987
# 2   32.078900
# 3   32.552982
# 4   32.345857
# 5   32.856199
# 6   31.164241
# 7   29.832090
# 8   31.010907
# 9   32.141890
# 10  43.054270
# 11  42.253401
# 12  41.080757
# 13  38.891757
# 14  37.717567
# 15  36.206725
# 16  34.518374
# 17  32.956879
# 18  30.545795
# 19  28.924331

# %%
# final course cohort regardless of tertiary type

final_student_df = total_intake_df.groupby('year').sum().sum(
    level=['year']).reset_index()

final_student_df
# Out:
#    year  intake  enrolment  graduates
# 0  2010    4626      15240       4324
# 1  2011    4999      15332       4315
# 2  2012    5004      15530       4406
# 3  2013    4842      15680       4347
# 4  2014    4463      15298       4574
# 5  2015    4284      14564       4479
# 6  2016    4148      14008       4356
# 7  2017    4488      14126       4066
# 8  2018    4859      14681       3991
# 9  2019    5171      15725       3734

# %% [markdown]
# ### Manipulation of Employment Datasets

# %%
#import employment change csv
employ_change_df = pd.read_csv('employment-change-by-industry-level3.csv')
employ_change_df.head()
# Out:
#    year      industry1                      industry2  \
# 0  1991         others                         others
# 1  1991   construction                   construction
# 2  1991  manufacturing    food, beverages and tobacco
# 3  1991  manufacturing    textile and wearing apparel
# 4  1991  manufacturing  paper products and publishing
#
#                        industry3 employment_change
# 0                         others              -0.1
# 1                   construction              17.7
# 2    food, beverages and tobacco               0.1
# 3    textile and wearing apparel              -2.4
# 4  paper products and publishing               0.8

# %%
# create DF with from years 2010 - 2019 + only selected industry3

# filter employ_change_df to years 2010 - 2019
mask2 = (employ_change_df['year'] > 2009) & (employ_change_df['year'] <= 2019)
filtered_employ_change_year = employ_change_df.loc[mask2]

# filter to industry - it and other information services
filtered_employ_change_year = filtered_employ_change_year[filtered_employ_change_year['industry3'] 
                                                          == 'it and other information services']


filtered_employ_change_year.reset_index(drop=True)

# as this is a small DF where everything is visible at one glance, we don't observe the DF.
# Out:
#    year industry1                       industry2  \
# 0  2010  services  information and communications
# 1  2011  services  information and communications
# 2  2012  services  information and communications
# 3  2013  services  information and communications
# 4  2014  services  information and communications
# 5  2015  services  information and communications
# 6  2016  services  information and communications
# 7  2017  services  information and communications
# 8  2018  services  information and communications
# 9  2019  services  information and communications
#
#                            industry3 employment_change
# 0  it and other information services               6.7
# 1  it and other information services               7.8
# 2  it and other information services               2.9
# 3  it and other information services               5.1
# 4  it and other information services               6.2
# 5  it and other information services               3.8
# ...

# %%
#import employment recruiment resignation csv
employ_recruit_df = pd.read_csv('average-monthly-recruitment-resignation-rate-by-industry-level-3.csv')
employ_recruit_df.head()
# Out:
#    year      industry1                        industry2  \
# 0  1990  manufacturing      food, beverages and tobacco
# 1  1990  manufacturing      textile and wearing apparel
# 2  1990  manufacturing    paper products and publishing
# 3  1990  manufacturing  petroleum and chemical products
# 4  1990  manufacturing      rubber and plastic products
#
#                          industry3  recruitment_rate  resignation_rate
# 0      food, beverages and tobacco               3.8               3.2
# 1      textile and wearing apparel               3.4               3.8
# 2    paper products and publishing               3.7               3.1
# 3  petroleum and chemical products               2.6               2.1
# 4      rubber and plastic products               4.9               4.3

# %%
# create DF with from years 2010 - 2019 + only selected industry3

# filter employ_change_df to 2010 - 2019
mask3 = (employ_recruit_df['year'] > 2009) & (employ_recruit_df['year'] <= 2019)
filtered_employ_recruit_year = employ_recruit_df.loc[mask3]

# filter to industry - it and other information services + architectural and engineering services
filtered_employ_recruit_year = filtered_employ_recruit_year[filtered_employ_recruit_year['industry3'] 
                                                            == 'it and other information services']


filtered_employ_recruit_year.reset_index(drop=True)

# as this is a small DF where everything is visible at one glance, we don't observe the DF.
# Out:
#    year industry1                       industry2  \
# 0  2010  services  information and communications
# 1  2011  services  information and communications
# 2  2012  services  information and communications
# 3  2013  services  information and communications
# 4  2014  services  information and communications
# 5  2015  services  information and communications
# 6  2016  services  information and communications
# 7  2017  services  information and communications
# 8  2018  services  information and communications
# 9  2019  services  information and communications
#
#                            industry3  recruitment_rate  resignation_rate
# 0  it and other information services               3.9               2.5
# 1  it and other information services               3.3               2.0
# 2  it and other information services               2.9               2.2
# 3  it and other information services               3.0               2.2
# ...

# %%
# as DF filtered_employ_recruit_year & DF filtered_employ_change_year are the same, other than the percentage columns,
# we can merge the 2 DFs.

# add recruitment rate column to DF filtered_employ_change_year
filtered_employ_change_year['recruitment_rate'] = filtered_employ_recruit_year['recruitment_rate'].values

# add resignation rate column to DF filtered_employ_change_year
filtered_employ_change_year['resignation_rate'] = filtered_employ_recruit_year['resignation_rate'].values

# create final DF with only relevant columns
employ_trend_df = filtered_employ_change_year[['year','industry3','employment_change','recruitment_rate',
                                                     'resignation_rate']]

# rename column industry3
final_employ_trend_df = employ_trend_df.rename(columns={'industry3':'industry'})

final_employ_trend_df.reset_index(drop=True)
# Out:
#    year                           industry employment_change  \
# 0  2010  it and other information services               6.7
# 1  2011  it and other information services               7.8
# 2  2012  it and other information services               2.9
# 3  2013  it and other information services               5.1
# 4  2014  it and other information services               6.2
# 5  2015  it and other information services               3.8
# 6  2016  it and other information services               3.2
# 7  2017  it and other information services               4.3
# 8  2018  it and other information services               7.9
# 9  2019  it and other information services                 7
#
#    recruitment_rate  resignation_rate
# 0               3.9               2.5
# 1               3.3               2.0
# 2               2.9               2.2
# 3               3.0               2.2
# 4               3.3               2.0
# 5               3.0               2.0
# ...

# %% [markdown]
# ### Visualisation of Data

# %%
import matplotlib.pyplot as plt


intake_df = final_student_df[['year','intake']]


# Convert to float so the y-axis values on the right side will be in order.
def convert_float(x):
    return(float(x))

final_employ_trend_df['employment_change'] = final_employ_trend_df['employment_change'].apply(convert_float)

# %%
# Graph of employment change and Student Intake

ax = intake_df.plot.bar(x='year', y='intake', rot=0, color = 'green', label = 'Intake')
plt.ylim([4000, 5500])
ax2 = ax.twinx()
ax2.plot( ax.get_xticks(), final_employ_trend_df['employment_change'].values, linestyle='-', marker='o', linewidth=2.0, label = 'employment change' )
plt.legend()
plt.title('Employment Change and Intake for IT' )
plt.show()

# %% [markdown]
# <p> There appears to be little to no correlation between these 2 variables. </p>

# %%
graduates_df = final_student_df[['year','graduates']]
intake_df = final_student_df[['year','intake']]
enrol_df = final_student_df[['year','enrolment']]

# %%
# Graph for Employment Change and Number of Graduates
ax = graduates_df.plot.bar(x='year', y='graduates', rot=0, color = 'green', label = 'Graduates')
plt.ylim([3500, 4800])
ax2 = ax.twinx()
ax2.plot( ax.get_xticks(), final_employ_trend_df['employment_change'].values, linestyle='-', marker='o', linewidth=2.0, label = 'employment change' )
plt.legend()
plt.title('Employment Change and Grads for IT' )
plt.show()

# %% [markdown]
# <p> There appears to be little to no correlation between these 2 variables. </p>

# %%
def convert_float(x):
    return(float(x))
final_employ_trend_df['recruitment_rate'] = final_employ_trend_df['recruitment_rate'].apply(convert_float)

# %%
# Graph for Recruitment Rate and Number of Graduates
ax = graduates_df.plot.bar(x='year', y='graduates', rot=0, color = 'red', label = 'Graduates')
plt.ylim([3500, 4600])

ax2 = ax.twinx()
ax2.plot( ax.get_xticks(), final_employ_trend_df['recruitment_rate'].values, linestyle='-', marker='o', linewidth=2.0, label = 'Recruitment' )
plt.legend(loc = 2)
plt.title('Recruitment Rate and Graduates for IT' )
plt.show()

# %% [markdown]
# <p> There appears to be little to no correlation between these 2 variables. </p>

# %%
# Rows 0 to 9 belong to Uni, rows 10 to 19 belong to polytechnic

proportion['year'] = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
uni_proportion = proportion[ :10]
poly_proportion = proportion[ 10:]


# Visualising proportion of female enrolment for poly and uni.
plt.plot( 'year', 'enrolment', data=uni_proportion, marker='o', markerfacecolor='blue', markersize=6, color='skyblue', linewidth=2, label='University')
plt.plot( 'year', 'enrolment', data=poly_proportion, marker='o', color='olive', linewidth=2, label='Polytechnic')
plt.ylabel('Proportion of females (%)')
plt.xlabel('Year')
plt.title('Proportion of female enrolment per year')
plt.legend()
plt.show()

# %% [markdown]
# <p>There is an increasing trend for university from 2010 to 2015 and and a decrease from 2015 to 2017, before increasing from 2017 to 2019.
#    For polytechnic, there has beem a decrease all the way from 2010 to 2019. </p>

# %% [markdown]
# ## Conclusion
# -In conclusion, it appears that there is not much correlation between the number of uni/poly grads and the increase in employment and recruitment rate for the IT industry and vice versa.
# This could be do to certain factors or variables that were not accounted for, such as students not pursuing a career in the IT industry despite studying IT in uni or poly.
#
# -There has been a decreasing trend in number of females in IT related poly courses and a slight increasing trend for number of females in university IT courses. The decrease could be due to changing preferences in choice of polytechnic courses. Perhaps more females are choosing other courses instead of IT, hence leading to a decrease in female in polytechnic IT courses.
